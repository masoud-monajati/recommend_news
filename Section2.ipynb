# %%
import numpy as np
init=(0,0)
   
prevdict={init:1}
thisdict={}
count=0

for i in range(2):
    for point in prevdict:
        for n in range(len(init)):
            if point[n]== 0:
                if(i==1):
                    count+=1*prevdict[point]
                else:         
                    new_member=list(point)
                    new_member[n]=1
                    if(tuple(new_member) in thisdict):
                        thisdict[tuple(new_member)]+=prevdict[point]
                    else:
                        thisdict[tuple(new_member)]=prevdict[point]
            else:
                if(i==1):
                    count+=2*prevdict[point]
                else:
                    new_member=list(point)
                    new_member[n]+=1
                    if(tuple(new_member) in thisdict):
                        thisdict[tuple(new_member)]+=prevdict[point]
                    else:
                        thisdict[tuple(new_member)]=prevdict[point]
                    new_member==list(point)
                    new_member[n]-=1
                    if(tuple(new_member) in thisdict):
                        thisdict[tuple(new_member)]+=prevdict[point]
                    else:
                        thisdict[tuple(new_member)]=prevdict[point]
    prevdict=thisdict.copy()
    #thisdict={}
    print('location',i,'finished!')

print(count)
# Out:
# location 0 finished!
# location 1 finished!
# 6

# %%
print(thisdict)
# Out:
# {(1, 0): 1, (0, 1): 1}

# %%
import numpy as np
init=(0,0,0,0)
   
prevdict={init:1}
thisdict={}
count=0
border=11
for i in range(12):
    for point in prevdict:
        for n in range(len(init)):
            if point[n]== 0:         
                new_member=list(point)
                new_member[n]=1
                if(tuple(new_member) in thisdict):
                    thisdict[tuple(new_member)]+=prevdict[point]
                else:
                    thisdict[tuple(new_member)]=prevdict[point]
            else:
                new_member=list(point)
                if(new_member[n]+1<=border):
                    new_member[n]+=1
                    if(tuple(new_member) in thisdict):
                        thisdict[tuple(new_member)]+=prevdict[point]
                    else:
                        thisdict[tuple(new_member)]=prevdict[point]
                new_member=list(point)
                new_member[n]-=1
                if(tuple(new_member) in thisdict):
                    thisdict[tuple(new_member)]+=prevdict[point]
                else:
                    thisdict[tuple(new_member)]=prevdict[point]
    prevdict=thisdict.copy()
    thisdict={}
    print('location',i,'finished!')
# Out:
# location 0 finished!
# location 1 finished!
# location 2 finished!
# location 3 finished!
# location 4 finished!
# location 5 finished!
# location 6 finished!
# location 7 finished!
# location 8 finished!
# location 9 finished!
# location 10 finished!
# location 11 finished!

# %%
print(sum(prevdict.values()))
# Out:
# 2479092118264

# %%
print(sum(prevdict.values()))
# Out:
# 281407110705872

# %%
print(sum(prevdict.values()))
# Out:
# 281407110705872

# %%
import numpy as np
list_walking=[]

for i1 in range(5):
    for i2 in range(5):
        for i3 in range(5):
            for i4 in range(5):
                init=(i1,i2,i3,i4)

                prevdict={init:1}
                thisdict={}
                count=0
                border=9
                for i in range(10):
                    for point in prevdict:
                        for n in range(len(init)):
                            if point[n]== 0:         
                                new_member=list(point)
                                new_member[n]=1
                                if(tuple(new_member) in thisdict):
                                    thisdict[tuple(new_member)]+=prevdict[point]
                                else:
                                    thisdict[tuple(new_member)]=prevdict[point]
                            else:
                                new_member=list(point)
                                if(new_member[n]+1<=border):
                                    new_member[n]+=1
                                    if(tuple(new_member) in thisdict):
                                        thisdict[tuple(new_member)]+=prevdict[point]
                                    else:
                                        thisdict[tuple(new_member)]=prevdict[point]
                                new_member=list(point)
                                new_member[n]-=1
                                if(tuple(new_member) in thisdict):
                                    thisdict[tuple(new_member)]+=prevdict[point]
                                else:
                                    thisdict[tuple(new_member)]=prevdict[point]
                    prevdict=thisdict.copy()
                    thisdict={}
                    print('location',i,'finished!')
                
                list_walking.append(sum(prevdict.values()))
# Out:
# location 0 finished!
# location 1 finished!
# location 2 finished!
# location 3 finished!
# location 4 finished!
# location 5 finished!
# location 6 finished!
# location 7 finished!
# location 8 finished!
# location 9 finished!
# location 0 finished!
# location 1 finished!
# location 2 finished!
# location 3 finished!
# location 4 finished!
# location 5 finished!
# location 6 finished!
# location 7 finished!
# location 8 finished!
# location 9 finished!
# location 0 finished!
# location 1 finished!
# location 2 finished!
# location 3 finished!
# location 4 finished!
# location 5 finished!
# location 6 finished!
# location 7 finished!
# location 8 finished!
# location 9 finished!
# location 0 finished!
# location 1 finished!
# location 2 finished!
# location 3 finished!
# location 4 finished!
# location 5 finished!
# location 6 finished!
# location 7 finished!
# location 8 finished!
# location 9 finished!
# location 0 finished!
# location 1 finished!
# location 2 finished!
# ...

# %%
np.std(list_walking)/np.mean(list_walking)
# Out:
# 0.5106573744484553

# %%
np.std(list_walking)/np.mean(list_walking)
# Out:
# 0.5106573744484553

# %%
len(list_walking)
# Out:
# 10000

# %%
import numpy as np
list_walking=[]

for i1 in range(6):
    for i2 in range(6):
        for i3 in range(6):
            for i4 in range(6):
                for i5 in range(6):
                    for i6 in range(6):
                        for i7 in range(6):
                            for i8 in range(6):
                                init=(i1,i2,i3,i4,i5,i6,i7,i8)

                                prevdict={init:1}
                                thisdict={}
                                count=0
                                border=11
                                for i in range(12):
                                    for point in prevdict:
                                        for n in range(len(init)):
                                            if point[n]== 0:         
                                                new_member=list(point)
                                                new_member[n]=1
                                                if(tuple(new_member) in thisdict):
                                                    thisdict[tuple(new_member)]+=prevdict[point]
                                                else:
                                                    thisdict[tuple(new_member)]=prevdict[point]
                                            else:
                                                new_member=list(point)
                                                if(new_member[n]+1<=border):
                                                    new_member[n]+=1
                                                    if(tuple(new_member) in thisdict):
                                                        thisdict[tuple(new_member)]+=prevdict[point]
                                                    else:
                                                        thisdict[tuple(new_member)]=prevdict[point]
                                                new_member=list(point)
                                                new_member[n]-=1
                                                if(tuple(new_member) in thisdict):
                                                    thisdict[tuple(new_member)]+=prevdict[point]
                                                else:
                                                    thisdict[tuple(new_member)]=prevdict[point]
                                    prevdict=thisdict.copy()
                                    thisdict={}

                                list_walking.append(sum(prevdict.values()))
    print('done')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-dcb1dc67d571> in <module>()
#      37                                                 new_member[n]-=1
#      38                                                 if(tuple(new_member) in thisdict):
# ---> 39                                                     thisdict[tuple(new_member)]+=prevdict[point]
#      40                                                 else:
#      41                                                     thisdict[tuple(new_member)]=prevdict[point]
#
# KeyboardInterrupt:
