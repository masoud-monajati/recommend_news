# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
data = pd.read_csv('Arrest_Data_from_2010_to_Present (1).csv')

data
# Out:
#          Report ID Arrest Date    Time  Area ID    Area Name  \
# 0          4248313  02/24/2015  1310.0       20      Olympic
# 1        191811472  05/03/2019  1700.0       18    Southeast
# 2          4254777  02/26/2015  2010.0       19      Mission
# 3          5614161  04/29/2019  1040.0        8      West LA
# 4          5615197  04/30/2019   615.0        6    Hollywood
# 5          5615701  04/30/2019  1100.0        9     Van Nuys
# 6          4256466  02/28/2015  1430.0       18    Southeast
# 7          4256564  02/28/2015  1715.0       10  West Valley
# 8          5616892  05/01/2019  1710.0       12  77th Street
# 9          5617003  05/01/2019  1010.0       16     Foothill
# 10         4256815  03/01/2015   110.0       17   Devonshire
# 11         5618079  05/02/2019  1520.0       14      Pacific
# 12         4257858  03/02/2015  1710.0        1      Central
# 13       190112234  04/16/2019  1450.0        1      Central
# ...

# %%
new = data["Arrest Date"].str.split("/", n = 2, expand = True) 

data["month"]= new[0] 
  
data["day"]= new[1] 

data["year"]= new[2] 

data
# Out:
#          Report ID Arrest Date    Time  Area ID    Area Name  \
# 0          4248313  02/24/2015  1310.0       20      Olympic
# 1        191811472  05/03/2019  1700.0       18    Southeast
# 2          4254777  02/26/2015  2010.0       19      Mission
# 3          5614161  04/29/2019  1040.0        8      West LA
# 4          5615197  04/30/2019   615.0        6    Hollywood
# 5          5615701  04/30/2019  1100.0        9     Van Nuys
# 6          4256466  02/28/2015  1430.0       18    Southeast
# 7          4256564  02/28/2015  1715.0       10  West Valley
# 8          5616892  05/01/2019  1710.0       12  77th Street
# 9          5617003  05/01/2019  1010.0       16     Foothill
# 10         4256815  03/01/2015   110.0       17   Devonshire
# 11         5618079  05/02/2019  1520.0       14      Pacific
# 12         4257858  03/02/2015  1710.0        1      Central
# 13       190112234  04/16/2019  1450.0        1      Central
# ...

# %%
t=data["Location"][0].split(",")[0].split("(")[1]
float(t)
# Out:
# 34.0653

# %%
n=0
for i in range(len(data)):
    if data["year"][i]=='2018':
        n+=1
n
# Out:
# 104277

# %%
data1=data.loc[(data['year']=='2018') | (data['year']=='2017') | (data['year']=='2016')| 
               (data['year']=='2015')| (data['year']=='2014')| (data['year']=='2013')| 
               (data['year']=='2012')| (data['year']=='2011')| (data['year']=='2010')]
data1
# Out:
#          Report ID Arrest Date    Time  Area ID    Area Name  \
# 0          4248313  02/24/2015  1310.0       20      Olympic
# 2          4254777  02/26/2015  2010.0       19      Mission
# 6          4256466  02/28/2015  1430.0       18    Southeast
# 7          4256564  02/28/2015  1715.0       10  West Valley
# 10         4256815  03/01/2015   110.0       17   Devonshire
# 12         4257858  03/02/2015  1710.0        1      Central
# 160        4738682  08/01/2016  1835.0        6    Hollywood
# 161        4738771  08/01/2016  1835.0        6    Hollywood
# 162        4988057  05/14/2017  2215.0        7     Wilshire
# 163        5060090  08/01/2017  2305.0       18    Southeast
# 164        5165092  11/27/2017  2215.0        7     Wilshire
# 165        5213460  01/24/2018  1930.0        6    Hollywood
# 166        5257944  03/15/2018   310.0        7     Wilshire
# 167        5328813  06/01/2018  1800.0        3    Southwest
# ...

# %%
data2=data1

# %%
data2.groupby('Address').size()
# Out:
# Address
# 00    19TH                         AV      3
# 00    26TH                         AV      1
# 00    27TH                         PL      1
# 00    28TH                         AV      1
# 00    29TH                         PL      1
# 00    46TH                         ST      1
# 00    BREEZE                       AV      2
# 00    BUCCANEER                    ST      3
# 00    CLUB HOUSE                   AV      1
# 00    DRIFTWOOD                    ST      1
# 00    DUDLEY                       AV      3
# 00    DUDLEY                       CT      1
# 00    GATEWAY                      PL      1
# 00    GATEWAY PLAZ                 DR      6
# 00    GATEWAY PLAZ                 ST      1
# 00    GATEWAY PLAZA                DR      4
# 00    HAVALON                      ST      1
# 00    LOYOLA MARYM                 DR      1
# 00    LOYOLA MARYMOUNT             DR      1
# 00    MANCHESTER                   BL      1
# 00    NAVY                         CT      1
# ...

# %%
data3=data1.loc[((data['Charge Group Description']=='Vehicle Theft') | 
                (data['Charge Group Description']=='Robbery') |
                (data['Charge Group Description']=='Burglary') | 
                (data['Charge Group Description']=='Receive Stolen Property'))]
data3
# Out:
#          Report ID Arrest Date    Time  Area ID    Area Name  \
# 178        5449454  10/15/2018  2330.0        1      Central
# 179        5449463  10/15/2018  2330.0        1      Central
# 180        5452727  10/19/2018  1935.0        1      Central
# 182        5460361  10/29/2018  1550.0       12  77th Street
# 183        5464308  11/03/2018   350.0        1      Central
# 184        5471809  11/12/2018  2315.0        1      Central
# 185        5476070  11/18/2018   300.0        1      Central
# 191        5482231  11/26/2018  2320.0       20      Olympic
# 192        5485057  11/30/2018   840.0        1      Central
# 203        5504278  12/24/2018  1000.0       14      Pacific
# 205        5505591  12/26/2018  1850.0       12  77th Street
# 206        5508766  12/30/2018   730.0       13       Newton
# 223        5495660  12/13/2018  2155.0       13       Newton
# 2591       5254360  03/10/2018  2125.0       10  West Valley
# ...

# %%
data3.reset_index(inplace = True) 
   
# display 
data3
# Out:
#       level_0    index  Report ID Arrest Date    Time  Area ID    Area Name  \
# 0           0      178    5449454  10/15/2018  2330.0        1      Central
# 1           1      179    5449463  10/15/2018  2330.0        1      Central
# 2           2      180    5452727  10/19/2018  1935.0        1      Central
# 3           3      182    5460361  10/29/2018  1550.0       12  77th Street
# 4           4      183    5464308  11/03/2018   350.0        1      Central
# 5           5      184    5471809  11/12/2018  2315.0        1      Central
# 6           6      185    5476070  11/18/2018   300.0        1      Central
# 7           7      191    5482231  11/26/2018  2320.0       20      Olympic
# 8           8      192    5485057  11/30/2018   840.0        1      Central
# 9           9      203    5504278  12/24/2018  1000.0       14      Pacific
# 10         10      205    5505591  12/26/2018  1850.0       12  77th Street
# ...

# %%
data3['Age'][1]
# Out:
# 41

# %%
import numpy as np
a=[]
for i in range(len(data3)):
    a.append(data3['Age'][i])  
a
# Out:
# [43,
#  32,
#  26,
#  32,
#  27,
#  20,
#  25,
#  18,
#  38,
#  27,
#  39,
#  26,
#  21,
#  26,
#  20,
#  31,
#  38,
#  25,
#  34,
#  32,
#  38,
#  21,
#  24,
#  59,
#  18,
#  19,
#  37,
#  33,
#  31,
#  19,
#  28,
#  17,
#  45,
#  34,
#  27,
#  31,
#  28,
#  43,
#  30,
#  28,
#  22,
#  20,
#  32,
#  35,
#  55,
#  36,
#  27,
#  31,
#  27,
#  19,
#  26,
#  43,
#  31,
#  17,
#  30,
#  27,
#  30,
#  33,
#  20,
#  55,
#  48,
#  48,
#  51,
#  30,
#  33,
#  28,
#  19,
#  48,
#  35,
#  57,
#  57,
#  27,
#  27,
#  19,
#  18,
#  44,
#  43,
#  25,
#  32,
#  53,
#  47,
#  27,
#  38,
#  19,
#  19,
#  30,
#  25,
#  63,
#  33,
#  37,
#  18,
#  24,
#  30,
#  36,
#  21,
#  14,
#  19,
#  34,
#  37,
#  36,
#  36,
#  28,
#  38,
#  25,
#  23,
#  28,
#  26,
#  17,
#  24,
#  28,
#  18,
#  40,
#  37,
#  55,
#  25,
#  34,
#  27,
#  35,
#  25,
#  18,
#  17,
#  18,
#  24,
#  18,
#  32,
#  33,
#  30,
#  20,
#  22,
#  30,
#  44,
#  34,
#  21,
#  24,
#  46,
#  37,
#  20,
#  28,
#  24,
#  27,
#  39,
#  23,
# ...

# %%
np.percentile(a,95)
# Out:
# 52.0

# %%
data2=data1

# %%
data2 = data2[pd.notnull(data2['Charge Group Description'])]

# %%
Crim_group=data2['Charge Group Description'].unique()

# %%
Crim_group
np.asarray(Crim_group)
Crim_group
# Out:
# array(['Fraud/Embezzlement', 'Homicide', 'Narcotic Drug Laws',
#        'Weapon (carry/poss)', 'Other Assaults',
#        'Miscellaneous Other Violations', 'Vehicle Theft',
#        'Aggravated Assault', 'Driving Under Influence', 'Robbery',
#        'Burglary', 'Against Family/Child', 'Moving Traffic Violations',
#        'Larceny', 'Forgery/Counterfeit', 'Receive Stolen Property',
#        'Sex (except rape/prst)', 'Prostitution/Allied', 'Liquor Laws',
#        'Drunkeness', 'Rape', 'Disturbing the Peace',
#        'Non-Criminal Detention', 'Disorderly Conduct', 'Gambling',
#        'Pre-Delinquency', 'Federal Offenses'], dtype=object)

# %%
from scipy import stats
z=[]
for i in range(len(Crim_group)):
    if 'Pre-Delinquency' not in Crim_group[i] and 'Non-Criminal Detention' not in Crim_group[i]:
        a=[]
        t=Crim_group[i]
        df=data1.loc[data1['Charge Group Description']==t]
        df.reset_index(inplace = True)
        for j in range(len(df)):
            a.append(df['Age'][j])
        z.append(np.mean(a)) 
r=stats.zscore(a)
print(stats.zscore(a))
# Out:
# [-0.22892611  0.32137704  2.41252899 -0.44904737 -1.76977492 -1.43959303
#  -1.10941114  0.43143767  1.20186207  1.09180144 -0.00880485 -0.99935051
#   0.21131641 -0.44904737 -0.22892611  0.87168018  0.65155893 -0.22892611
#  -0.88928988  0.43143767  2.08234711 -0.33898674 -0.33898674 -1.21947177
#  -0.00880485]

# %%
max(r)
# Out:
# 2.4125289940202044

# %%
data5=data
year=data5['year'].unique()
year.sort()
year
# Out:
# array(['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019'], dtype=object)

# %%
x=[]
for i in range(len(year)-1):
    df=data5.loc[data5['year']==year[i]]
    df=df.loc[df['Arrest Type Code']=='F']
    x.append(len(df))

# %%
x
x=np.asarray(x)
x
# Out:
# array([51157, 49830, 50610, 47882, 45878, 35709, 36880, 35974, 34948])

# %%
y=[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
       2018]

# %%
y
y=np.asarray(y)
y
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018])

# %%
y=y.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(y,x)
reg.predict(np.array([2019]).reshape(-1, 1))
# Out:
# array([[31037.80555556]])

# %%
data1
# Out:
#          Report ID Arrest Date    Time  Area ID    Area Name  \
# 165        5213460  01/24/2018  1930.0        6    Hollywood
# 166        5257944  03/15/2018   310.0        7     Wilshire
# 167        5328813  06/01/2018  1800.0        3    Southwest
# 168        5336331  06/10/2018   200.0       13       Newton
# 169        5360731  07/07/2018  2330.0       18    Southeast
# 170        5404690  08/25/2018  1850.0       18    Southeast
# 171        5406551  08/27/2018  2300.0       18    Southeast
# 176        5419122  09/10/2018  1620.0       12  77th Street
# 177        5430543  09/23/2018  1830.0       13       Newton
# 178        5449454  10/15/2018  2330.0        1      Central
# 179        5449463  10/15/2018  2330.0        1      Central
# 180        5452727  10/19/2018  1935.0        1      Central
# 181        5456681  10/25/2018    30.0        6    Hollywood
# 182        5460361  10/29/2018  1550.0       12  77th Street
# ...

# %%
data1.reset_index(inplace = True)

# %%
lon_list=[]
lat_list=[]
for i in range(len(data1)):
    if 'PICO' in data1['Address'][i]:
        print(data1['Address'][i])
        location=data1["Location"][i]
        
        t=location.split(",")[0].split("(")[1]
        lon=float(t)
        
        lon_list.append(lon)
        
        t=location.split(",")[1].split(")")[0]
        lat=float(t)
        
        lat_list.append(lat)
# Out:
# PICO                         BL
# PICO                         BL
# PICO                         BL
# 2500 W  PICO                         BL
# PICO                         BL
# PICO
# 4500 W  PICO                         BL
# PICO
# PICO
# PICO
# 10500 W  PICO                         BL
# PICO                         BL
# PICO
# PICO                         BL
# PICO                         BL
# 300 W  PICO                         BL
# 300 W  PICO                         BL
# 400 W  PICO                         BL
# PICO                         BL
# PICO
# 400 W  PICO                         BL
# PICO
# 100 W  PICO                         BL
# PICO
# 300 W  PICO                         BL
# PICO
# PICO
# 1800 W  PICO                         BL
# PICO
# 1400 W  PICO                         BL
# PICO
# 1400 W  PICO                         BL
# 1400 W  PICO                         BL
# PICO
# PICO                         BL
# PICO                         BL
# ...

# %%
len(final_lon_list)
# Out:
# 605

# %%
final_lon_list=[]
final_lat_list=[]

elements_lon = np.array(lon_list)

mean_lon = np.mean(elements_lon, axis=0)
sd_lon = np.std(elements_lon, axis=0)

elements_lat = np.array(lat_list)

mean_lat = np.mean(elements_lat, axis=0)
sd_lat = np.std(elements_lat, axis=0)

for i in range(len(lon_list)):
    if (lon_list[i] > mean_lon - 2* sd_lon and lon_list[i] < mean_lon + 2* sd_lon) and (lat_list[i] > mean_lat - 2* sd_lat and lat_list[i] < mean_lat + 2* sd_lat):
        final_lon_list.append(lon_list[i]) 
        final_lat_list.append(lat_list[i])

# %%
print(min(final_lat_list))
print(max(final_lat_list))
# Out:
# -118.453
# -118.2159

# %%
for i in range(len(final_lat_list)):
    if final_lat_list[i]==-118.453:
        print(final_lon_list[i])
# Out:
# 34.0281
# 34.0281
# 34.0281
# 34.0281
# 34.0281
# 34.0281
# 34.0281
# 34.0281
# 34.0281
# 34.0281
# 34.0281
# 34.0281

# %%
import math
R= 6373

dlon = (34.0281 - 34.0188)*(math.pi/180)
dlat = ((-118.453) - (-118.2159))*(math.pi/180)
    
phi=(34.0281 + 34.0188)*(math.pi/180)/2
    
d = R * math.sqrt(dlon**2+(math.cos(phi)*dlat)**2)
d
# Out:
# 21.882297286039826

# %%
elements = np.array(lon_list)

mean = np.mean(elements, axis=0)
sd = np.std(elements, axis=0)

final_list_lon_list = [x for x in lon_list if (x > mean - 2 * sd)]
final_list_lon_list = [x for x in final_list_lon_list if (x < mean + 2 * sd)]

# %%
elements = np.array(lat_list)

mean = np.mean(elements, axis=0)
sd = np.std(elements, axis=0)

final_list_lat_list = [x for x in lat_list if (x > mean - 2 * sd)]
final_list_lat_list = [x for x in final_list_lat_list if (x < mean + 2 * sd)]

# %%
import numpy as np
a1=[1,1,1,1,1,5]
elements = np.array(a1)

mean = np.mean(elements, axis=0)
sd = np.std(elements, axis=0)

final_list = [x for x in a1 if (x > mean - 2 * sd)]
final_list = [x for x in final_list if (x < mean + 2 * sd)]
print(final_list)
# Out:
# [1, 1, 1, 1, 1]

# %%
import math
R= 6373
count=0
lon1=34.050536*(math.pi/180)
lat1=-118.247861*(math.pi/180)
data6.reset_index(inplace = True)
for i in range(len(data6)):
    t=data["Location"][i].split(",")[0].split("(")[1]
    lon2=float(t)*(math.pi/180)
    t=data["Location"][i].split(",")[1].split(")")[0]
    lat2=float(t)*(math.pi/180)
    
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    
    phi=(lon2 + lon1)/2
    
    d = R * math.sqrt(dlon**2+(math.cos(phi)*dlat)**2)
    
    if (d<=2):
        count+=1

# %%
count
# Out:
# 9643

# %%
data2 = data1[data1["Charge Group Code"] == 25]

# %%
data2
# Out:
#          Report ID Arrest Date    Time  Area ID    Area Name  \
# 59012      4216458  01/22/2015  1545.0       12  77th Street
# 60178      4979493  05/04/2017  1830.0        5       Harbor
# 462456     2191584  01/11/2010  1535.0        4   Hollenbeck
# 465406     2200878  01/20/2010    40.0       12  77th Street
# 465806     2200874  01/20/2010    40.0       12  77th Street
# 466169     2204482  01/23/2010  1830.0       14      Pacific
# 466622     2205442  01/24/2010  1950.0       19      Mission
# 469583     2217393  02/03/2010  2230.0       17   Devonshire
# 471977     2228091  02/13/2010   230.0        9     Van Nuys
# 472910     2228958  02/13/2010  2300.0       21      Topanga
# 474187     2233093  02/18/2010    30.0        4   Hollenbeck
# 474872     2239468  02/23/2010  1430.0       12  77th Street
# 475188     2238165  02/22/2010  1230.0       20      Olympic
# 476645     2243750  02/26/2010  1700.0        5       Harbor
# ...

# %%
bool_series = pd.notnull(data1["Charge Group Code"])    
data1=data1[bool_series]

# %%
Area_ID=data1['Area ID'].unique()
Area_ID
# Out:
# array([20, 19, 18, 10, 17,  1,  6,  7,  3, 13, 14, 12,  8,  9, 11,  4, 21,
#        15,  2, 16,  5], dtype=int64)

# %%
Crime_ID=data1['Charge Group Code'].unique()
Crime_ID
# Out:
# array([ 5.,  6.,  3.,  8., 10., 11.,  1., 16., 12.,  4., 24.,  7., 22.,
#        15., 13., 23.,  9., 14., 17., 18.,  2., 19., 21., 26., 27., 29.,
#        20., 25.])

# %%
len(data1)
# Out:
# 1151713

# %%
ratio=[]
for j in range(len(Crime_ID)):
    
    crime_ID_j= Crime_ID[j]
    
    df=data1[data1["Charge Group Code"] == crime_ID_j]
    count_city=len(df)
    
    prob_city=count_city/len(data1)
    
    for i in range(len(Area_ID)):
        
        area_count=0
        
        area_ID_i= Area_ID[i]
        
        df2=data1[data1["Area ID"] == area_ID_i]
        
        df1=df[df["Area ID"] == area_ID_i]
        
        area_count= len(df1)
        
        prob_area=area_count/len(df2)
        
        print(prob_area/prob_city)
        ratio.append(prob_area/prob_city)
# Out:
# 0.9703605629986944
# 1.14003431851962
# 1.5528360633129845
# 1.1655946367479908
# 1.1916153028519407
# 0.45030651999751364
# 0.5294870558932335
# 1.3355182455876182
# 1.2466093439599728
# 1.0513720825327248
# 0.7896298040816652
# 1.495640083876234
# 1.2050378571586648
# 0.9542907629427833
# 1.0219193773369235
# 0.9605978987870577
# 1.290076917926372
# 1.1044926171870195
# 0.7748216996406961
# 1.0921777605285403
# 1.248407157866063
# 0.595554300562197
# 1.0443303847593028
# 0.43661720649968083
# 0.8801271153007382
# 3.0127788295079814
# 0.6853340978511773
# 0.5271161165247029
# 1.8957084794162098
# 1.6893258194093008
# 0.31708117561648236
# 0.6029302897187044
# 0.7423832900457217
# 1.339442602872287
# 1.3594388867882097
# 1.1482032203100412
# 0.5390706173760517
# 2.8738559634947207
# 1.390935932696539
# 0.5559656026156855
# 0.7221291944715941
# 0.9233695480155095
# 1.3167963886401417
# 0.9086504301938103
# 2.145713669286479
# 0.7298113694487577
# 0.5983399938260701
# ...

# %%
final_list=[]
for i in range(0, 5):  
    max1 = 0

    for j in range(len(ratio)):      
        if ratio[j] > max1: 
            max1 = ratio[j]; 

    ratio.remove(max1); 
    final_list.append(max1) 

print(final_list)
# Out:
# [5.316477071726235, 3.1874535909681474, 3.1747631702095447, 3.0127788295079814, 2.8839092369141026]

# %%
np.mean(final_list)
# Out:
# 3.515076379865202

# %%
for n in range(len(data1)):
    if data1["Charge Group Code"][n]=='NaN':
        print('ok')
